# %%
import matplotlib.pyplot as plt

# Define a variable containing the LaTeX-formatted string you want to insert
variable_value = r'$^{12}Clamp^{13}C$'

# Create a non-LaTeX-formatted label with the variable value
# label = f'This is non-italic text with {variable_value}'
# label = 'This is non-italic text with ${$^{12}Clamp^{13}C$}$'
label = r'This is non-italic text with ${\rm ^{12}Clamp^{13}C}$'
# label = 'Primary T$_{eff}$'
# label = r'Primary T$_{\rm eff}$'

# Disable LaTeX rendering
# plt.rcParams['text.usetex'] = False

# Create a sample plot
plt.plot([1, 2, 3], [2, 4, 6])

# Add the label to the plot
plt.text(1, 6, label, fontsize=12)


# plt.xlabel(r'Primary T$_{\rm eff}$')

# Show the plot
plt.show()
