# %% [markdown]
# 1. Query say 150 records by PubChem ID
# 2. Run RDKit function to calculate Lipinski Rule of 5 properties (use Pat Walters' Ro5Calculator?)
#    1. Molecular weight <= 500
#    2. LogP <= 5.0
#    3. H-bond donor count <= 5
#    4. H-bond acceptor count <= 10
#    5. TPSA?
# 3. Store data (PubChem ID, SMILES, RDKit-computed properties) in sqlite database
# 4. Query database to count molecules by number of rings, other property
